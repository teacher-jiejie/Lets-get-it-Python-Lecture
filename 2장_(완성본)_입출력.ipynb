# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/Python/blob/main/2%EC%9E%A5_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EC%9E%85%EC%B6%9C%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 파이썬 명령어 형식
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/0_%EB%AA%85%EB%A0%B9%EC%96%B4.png?raw=true' width=400>

# %% [markdown]
# # 2. 출력명령어
# ### 출력 명령어 형식
#
#
# > print( 출력할 내용 )

# %%
# 숫자 출력 1030
print(1030)
# Out:
# 1030

# %%
# 문자 출력 10월 30일
print(10월 30일)
# Out:
#   File "<ipython-input-5-b4a8abfa80b5>", line 2
#     print(10월 30일)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 문자는 따옴표로 감싸주어야 함
# > print('문자')

# %%
# 문자는 따옴표로 감싸주어야 함
print('10월 30일')
# Out:
# 10월 30일

# %%
print(렛츠기릿파이썬)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1d1eabde5ef7> in <module>()
# ----> 1 print(렛츠기릿파이썬)
#
# NameError: name '렛츠기릿파이썬' is not defined

# %%
print('렛츠기릿파이썬')
# Out:
# 렛츠기릿파이썬

# %%
# 연산하여 출력하기
print(12+34)
print(12-34)
print(12*34)
print(12/34)
# Out:
# 46
# -22
# 408
# 0.35294117647058826

# %%
# 숫자라 하더라도 따옴표로 감싸면 문자로 인식
print('12+34')
# Out:
# 12+34

# %%
# ** 제곱
print(5**2)

# 몫
print(5//2)

# 나머지
print(5%2)
# Out:
# 25
# 2
# 1

# %% [markdown]
# ### 연결하여 출력하기
# > print(  ,  )
# <br/>
# > print(  +  )

# %%
# 콤마, 로 연결하여 출력하기
print('파이썬', '안녕!')
# Out:
# 파이썬 안녕!

# %%
# 더하기 +로 연결하여 출력하기
print('파이썬'+'안녕!')
# Out:
# 파이썬안녕!

# %%
print('파이썬', 12*34)
# Out:
# 파이썬 408

# %%
print('파이썬'+ 12*34)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-1272da14889d> in <module>()
# ----> 1 print('파이썬'+ 12*34)
#
# TypeError: must be str, not int

# %% [markdown]
# 실습 1. 본인 이름, 관심분야를 한 줄로 출력해보기

# %%
print('졔졔쌤', '인공지능')
# Out:
# 졔졔쌤 인공지능

# %% [markdown]
# # 3. 입력명령어
# ### 입력명령어 형식
# > input('입력안내문')

# %%
input()
# Out:
# 123123
# '123123'

# %%
input('생일 : ')
# Out:
# 생일 : 10월 30일
# '10월 30일'

# %%
input('아이디 : ')
# Out:
# 아이디 : letsgetit
# 'letsgetit'

# %%
input('아이디 : ')
input('비밀번호 : ')
# Out:
# 아이디 : jiejie
# 비밀번호 : 12341234
# '12341234'

# %% [markdown]
# ### 순차구조
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/66_%E1%84%89%E1%85%AE%E1%86%AB%E1%84%8E%E1%85%A1%E1%84%80%E1%85%AE%E1%84%8C%E1%85%A9.png?raw=true' width=600>

# %%
print('---000 웹사이트 회원가입 ---')
input('아이디 : ')
print('000 웹사이트 가입을 환영합니다!')
# Out:
# ---000 웹사이트 회원가입 ---
# 아이디 : jiejie
# 000 웹사이트 가입을 환영합니다!
