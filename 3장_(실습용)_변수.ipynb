# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/Python/blob/main/3%EC%9E%A5_(%EC%8B%A4%EC%8A%B5%EC%9A%A9)_%EB%B3%80%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 변수
#
#
# > 변수이름 = 저장할 데이터
#
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/%E1%84%87%E1%85%A7%E1%86%AB%E1%84%89%E1%85%AE%E1%84%8B%E1%85%B5%E1%84%86%E1%85%B5%E1%84%8C%E1%85%B5.png?raw=true' width =500>

# %% [markdown]
# ### 변수를 활용하여 연산하기
# 1) 과일 가격 계산하기

# %%
# 사과 3개, 바나나1개, 키위2개 구매한 가격은?

# %% [markdown]
# vip는 20% 할인된다. 동일한 물건을 구매했을 때 vip가 내는 가격을 새로운 변수에 저장하여 출력하기

# %% [markdown]
# 2) 1년마다 키가 10cm씩 자라는 농구선수가 있다.
#
#
# *   2017년 - 175.5cm
# *   2018년 - 185.5cm
# *   2019년 - 195.5cm
# *   2020년 - 205.5cm
#
#
# 년도별 농구선수의 키를 출력해보자

# %% [markdown]
# > 동일한 변수를 증가/감소시킬 때
#
# ```
# # a에 3을 더하시오
# a = a+3
# ```
#
# ```
# # 간략하게 표현
# a += 3
# ```

# %% [markdown]
# > 입력받아 저장하기

# %% [markdown]
# # 2. 데이터타입
#
# > 정수 int
#
# > 실수 float
#
# > 문자 str

# %% [markdown]
# # 3. 데이터타입 변경하기
# 변경하려는 데이터타입으로 감싸주기
#
# > 정수로 변경하기
# <br/> int(변수)
#
# > 실수로 변경하기
# <br/> float(변수)
#
# > 문자로 변경하기
# <br/> str(변수)

# %%
# 정수를 실수로

# %%
# 실수를 정수로

# %% [markdown]
# # 4. 원의 둘레, 넓이, 구의 겉넓이, 부피 구하기
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/36_%EC%9B%90%20%EB%84%93%EC%9D%B4,%20%EB%91%98%EB%A0%88%20%EB%93%B1.png?raw=true' width = 400>

# %% [markdown]
# 실습 : 반지름을 입력받아서, 입력받은 반지름을 갖는 원의 둘레, 넓이, 구 겉넓이, 부피를 구하시오

# %% [markdown]
# 윗 줄의 r과 아랫줄의 r은 동일하므로 두 줄을 한 줄로 줄여서 표현하기
#
#
# ```
# r = input('반지름은? ')
# r = int(r)
# type(r)
# ```
