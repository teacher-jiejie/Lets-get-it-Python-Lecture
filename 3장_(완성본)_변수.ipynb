# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/Python/blob/main/3%EC%9E%A5_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EB%B3%80%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 변수
#
#
# > 변수이름 = 저장할 데이터
#
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/%E1%84%87%E1%85%A7%E1%86%AB%E1%84%89%E1%85%AE%E1%84%8B%E1%85%B5%E1%84%86%E1%85%B5%E1%84%8C%E1%85%B5.png?raw=true' width =500>

# %%
a = '안녕'
print(a)
# Out:
# 안녕

# %%
print('a')
# Out:
# a

# %%
b = '학생'
c = '고등'
d = '대'
print(c+b)
# Out:
# 고등학생

# %%
print(d+b)
# Out:
# 대학생

# %% [markdown]
# ### 변수를 활용하여 연산하기
# 1) 과일 가격 계산하기

# %%
apple = 1200
banana = 800
kiwi = 1700

# %%
# 사과 3개, 바나나1개, 키위2개 구매한 가격은?
apple*3 + banana*1 + kiwi*2
# Out:
# 7800

# %%
price = apple*3 + banana*1 + kiwi*2
print(price)
# Out:
# 7800

# %% [markdown]
# vip는 20% 할인된다. 동일한 물건을 구매했을 때 vip가 내는 가격을 새로운 변수에 저장하여 출력하기

# %%
vip_price = price * 0.8

# %%
print('vip가 되시면',price,'원을',vip_price,'원에 구매 가능합니다! ')
# Out:
# vip가 되시면 7800 원을 6240.0 원에 구매 가능합니다!

# %% [markdown]
# 2) 1년마다 키가 10cm씩 자라는 농구선수가 있다.
#
#
# *   2017년 - 175.5cm
# *   2018년 - 185.5cm
# *   2019년 - 195.5cm
# *   2020년 - 205.5cm
#
#
# 년도별 농구선수의 키를 출력해보자

# %%
year = 2017
height = 175.5
print(year,'년 -', height,'cm')

year = year + 1
height = height + 10
print(year,'년 -', height,'cm')

year = year + 1
height = height + 10
print(year,'년 -', height,'cm')

year = year + 1
height = height + 10
print(year,'년 -', height,'cm')
# Out:
# 2017 년 - 175.5 cm
# 2018 년 - 185.5 cm
# 2019 년 - 195.5 cm
# 2020 년 - 205.5 cm

# %%
year = 2017
height = 175.5
print(year,'년 -', height,'cm')

year += 1
height += 10
print(year,'년 -', height,'cm')

year += 1
height += 10
print(year,'년 -', height,'cm')

year += 1
height += 10
print(year,'년 -', height,'cm')
# Out:
# 2017 년 - 175.5 cm
# 2018 년 - 185.5 cm
# 2019 년 - 195.5 cm
# 2020 년 - 205.5 cm

# %% [markdown]
# > 동일한 변수를 증가/감소시킬 때
#
# ```
# # a에 3을 더하시오
# a = a+3
# ```
#
# ```
# # 간략하게 표현
# a += 3
# ```

# %%
year /= 1

# %% [markdown]
# > 입력받아 저장하기

# %%
id = input('아이디 : ')
print('입력하신 아이디는', id)
# Out:
# 아이디 : jiejie
# 입력하신 아이디는 jiejie

# %% [markdown]
# # 2. 데이터타입
#
# > 정수 int
#
# > 실수 float
#
# > 문자 str

# %%
type(apple)
# Out:
# int

# %%
type(banana)
# Out:
# int

# %%
type(vip_price)
# Out:
# float

# %%
type(b)
# Out:
# str

# %% [markdown]
# # 3. 데이터타입 변경하기
# 변경하려는 데이터타입으로 감싸주기
#
# > 정수로 변경하기
# <br/> int(변수)
#
# > 실수로 변경하기
# <br/> float(변수)
#
# > 문자로 변경하기
# <br/> str(변수)

# %%
# 정수를 실수로 
print(apple)
apple = float(apple)
print(apple)
# Out:
# 1200
# 1200.0

# %%
# 실수를 정수로
print(vip_price)
vip_price = int(vip_price)
print(vip_price)
# Out:
# 1560.0
# 1560

# %% [markdown]
# # 4. 원의 둘레, 넓이, 구의 겉넓이, 부피 구하기
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/36_%EC%9B%90%20%EB%84%93%EC%9D%B4,%20%EB%91%98%EB%A0%88%20%EB%93%B1.png?raw=true' width = 400>

# %%
r = 5
p = 3.141592

# 원의 둘레
c_len = 2*p*r

# 원의 넓이
c_area = p*r**2

# 구의 겉넓이
s_area = 4*p*r**2

# 구의 부피 
s_volume = 4/3*p*r**3

print('원의 둘레는', c_len)
print('원의 넓이는', c_area)
print('구의 겉넓이는', s_area)
print('구의 부피는', s_volume)
# Out:
# 원의 둘레는 31.41592
# 원의 넓이는 78.5398
# 구의 겉넓이는 314.1592
# 구의 부피는 523.5986666666666

# %% [markdown]
# 실습 : 반지름을 입력받아서, 입력받은 반지름을 갖는 원의 둘레, 넓이, 구 겉넓이, 부피를 구하시오

# %%
r = input('반지름은? ')
p = 3.141592

# 원의 둘레
c_len = 2*p*r

# 원의 넓이
c_area = p*r**2

# 구의 겉넓이
s_area = 4*p*r**2

# 구의 부피 
s_volume = 4/3*p*r**3

print('원의 둘레는', c_len)
print('원의 넓이는', c_area)
print('구의 겉넓이는', s_area)
print('구의 부피는', s_volume)
# Out:
# 반지름은? 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9cd5e88e308b> in <module>()
#       3
#       4 # 원의 둘레
# ----> 5 c_len = 2*p*r
#       6
#       7 # 원의 넓이
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
input('반지름은? ')
# Out:
# 반지름은? 9
# '9'

# %%
r = input('반지름은? ')
# r = int(r)
type(r)
# Out:
# 반지름은? 9
# int

# %%
r = input('반지름은? ')
r = int(r)
p = 3.141592

# 원의 둘레
c_len = 2*p*r

# 원의 넓이
c_area = p*r**2

# 구의 겉넓이
s_area = 4*p*r**2

# 구의 부피 
s_volume = 4/3*p*r**3

print('원의 둘레는', c_len)
print('원의 넓이는', c_area)
print('구의 겉넓이는', s_area)
print('구의 부피는', s_volume)
# Out:
# 반지름은? 9
# 원의 둘레는 56.548656
# 원의 넓이는 254.468952
# 구의 겉넓이는 1017.875808
# 구의 부피는 3053.627424

# %% [markdown]
# 윗 줄의 r과 아랫줄의 r은 동일하므로 두 줄을 한 줄로 줄여서 표현하기
#
#
# ```
# r = input('반지름은? ')
# r = int(r)
# type(r)
# ```

# %%
r = int(input('반지름은? '))
type(r)
# Out:
# 반지름은? 9
# int

# %%
r = int(input('반지름은? '))
p = 3.141592

# 원의 둘레
c_len = 2*p*r

# 원의 넓이
c_area = p*r**2

# 구의 겉넓이
s_area = 4*p*r**2

# 구의 부피 
s_volume = 4/3*p*r**3

print('원의 둘레는', c_len)
print('원의 넓이는', c_area)
print('구의 겉넓이는', s_area)
print('구의 부피는', s_volume)
# Out:
# 반지름은? 9
# 원의 둘레는 56.548656
# 원의 넓이는 254.468952
# 구의 겉넓이는 1017.875808
# 구의 부피는 3053.627424
