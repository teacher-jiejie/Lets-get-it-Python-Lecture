# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/Lets-get-it-Python/blob/main/2%EC%9E%A5_(%EC%8B%A4%EC%8A%B5%EC%9A%A9)_%EC%9E%85%EC%B6%9C%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 파이썬 명령어 형식
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/0_%EB%AA%85%EB%A0%B9%EC%96%B4.png?raw=true' width=400>

# %% [markdown]
# # 2. 출력명령어
# ### 출력 명령어 형식
#
#
# > print( 출력할 내용 )

# %% [markdown]
# ### 문자는 따옴표로 감싸주어야 함
# > print('문자')

# %%
# 숫자라 하더라도 따옴표로 감싸면 문자로 인식

# %%
# ** 제곱


# 몫


# 나머지

# %% [markdown]
# ### 연결하여 출력하기
# > print(  ,  )
# <br/>
# > print(  +  )

# %%
# 콤마, 로 연결하여 출력하기

# %%
# 더하기 +로 연결하여 출력하기

# %% [markdown]
# 실습 1. 본인 이름, 관심분야를 한 줄로 출력해보기

# %% [markdown]
# # 3. 입력명령어
# ### 입력명령어 형식
# > input('입력안내문')

# %% [markdown]
# ### 순차구조
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/66_%E1%84%89%E1%85%AE%E1%86%AB%E1%84%8E%E1%85%A1%E1%84%80%E1%85%AE%E1%84%8C%E1%85%A9.png?raw=true' width=600>
