# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/Python/blob/main/4%EC%9E%A5_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EC%A1%B0%EA%B1%B4%EB%AC%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  1. 조건문 if
#
# **조건문 : 조건을 충족할 때에만 선택적으로 실행되는 명령어**
# </br>
# **=선택구조**
# </br>
#
#
# ```
# 조건 A를 충족할 때에만
# B해라
#
# ex. 성인일 때에만 주류를 판매해라
# ```
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/71_if.png?raw=true' width=500>

# %%
# 만약 미성년자라면 술을 구매할 수 없다고 출력
age = 20

if age < 20 : 
    # 조건을 충족할 때만 실행
    print('술을 구매할 수 없습니다.')

# %% [markdown]
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/10_%EC%84%A0%ED%83%9D%EA%B5%AC%EC%A1%B0%20%EB%8F%99%EC%9E%91%EC%9B%90%EB%A6%AC.png?raw=true' width =800>

# %% [markdown]
# > 조건문에서는 들여쓰기를 조심하세요!
# </br>
# <img src ='https://github.com/Ahnjihye/allinone_AI/blob/images/10_%EC%84%A0%ED%83%9D%EA%B5%AC%EC%A1%B0%20%EB%93%A4%EC%97%AC%EC%93%B0%EA%B8%B0%20png.png?raw=true' width=200>

# %% [markdown]
# 물건 금액을 입력받고 물건이 오만원 미만일 경우 배송비 2500원을 더해서 결제금액을 안내하시오.

# %%
price = int(input('물건 가격 입력 : '))

if price < 50000 : 
    price += 2500

print('총 결제금액은',price)
# Out:
# 물건 가격 입력 : 30000
# 총 결제금액은 32500

# %% [markdown]
# # 2. 조건을 만드는 비교연산자
#
# a와 b가 같다면
# > if a == b :
#
# </br>
#
# a와 b가 같지 않다면
#
# > if a != b :
#
# </br>
# </br>
#
# a가 b보다 크다면
# > if a > b :
#
# a가 b보다 크거나 같다면
# > if a >= b :
#
# a가 b보다 작다면
# > if a < b :
#
# a가 b보다 작거나 같다면
# > if a <= b :

# %% [markdown]
# 출석 혹은 결석 둘 중 하나를 입력받고, 출석을 입력받았을 경우 O를 출력하기

# %%
check = input('출석 혹은 결석을 입력하세요 ')
if check == '출석' : 
    print('0')
# Out:
# 출석 혹은 결석을 입력하세요 출석
# 0

# %% [markdown]
# # 3. if-else 조건문
# 조건을 충족하지 않을 때 실행하는 명령어
#
#
# ```
# 만약 조건 A라면,
#     B해라
# 그렇지 않으면,
#     C해라
# ```
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/70_else.png?raw=true' width=400>

# %%
if age < 20 : 
    print('술을 구매할 수 없습니다.')
else : 
    print('감사합니다. 안녕히 가세요.')
# Out:
# 감사합니다. 안녕히 가세요.

# %% [markdown]
# 자동 출석 시스템
# ```
# 출석 혹은 결석을 입력받아 출석이면 O을 출력, 출석이 아니면 X를 출력하기
# 입력안내문 : 출석 혹은 결석을 입력하세요
# ```

# %%
check = input('출석 혹은 결석을 입력하세요 ')
if check == '출석' : 
    print('0')
else : 
    print('X')
# Out:
# 출석 혹은 결석을 입력하세요 결석
# X

# %% [markdown]
# 무인계산기 프로그램
#
#
# ```
# 목욕탕에서 무인계산기를 설치했다.
# 성인 요금은 15000원, 미성년자 요금은 6000원이다.
# 나이를 입력받아 성인이면 price(요금을 저장하는 변수)에 15000을, 미성년자라면 6000을 저장하기
# ```

# %%
age = int(input('나이가 어떻게 되세요? '))

if age >= 20 : 
    price = 15000
    print('성인은', price, '원입니다.')
else : 
    price = 6000
    print('미성년자는', price, '원입니다.')
# Out:
# 나이가 어떻게 되세요? 35
# 성인은 15000 원입니다.

# %% [markdown]
# # 4. elif 조건문
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/68_elif.png?raw=true' width=400>

# %% [markdown]
# 최저 주문금액이 있는 새벽배송
#
#
# ```
# - 최저 구매금액이 2만 원
# - 5만 원 미만은 배송비 2500원 추가
# - 5만 원 이상 이면 무료배송
#
# 구매금액을 입력받아 조건 별로
# - '새벽배송이 불가합니다.'
# - '배송비 2500원이 추가됩니다.'
# - '무료배송됩니다.'
# 중 하나를 출력하기
# ```
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/67_elif.png?raw=true' width=600>

# %%
price = int(input('구매금액은?'))

if price < 20000 : 
    print('새벽배송이 불가능합니다.')
elif price < 50000 : 
    print('배송비 2500원이 추가됩니다.')
else : 
    print('무료배송 됩니다.')
# Out:
# 구매금액은?35000
# 배송비 2500원이 추가됩니다.
